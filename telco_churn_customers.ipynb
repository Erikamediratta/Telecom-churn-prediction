# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     18
# int64       2
# float64     1
# Name: count, dtype: int64

# %%
import seaborn as sns
ax=sns.countplot(x="Churn",data=df)
ax.bar_label(ax.containers[0])
plt.show()

# %%
ax=sns.countplot(x="gender",hue="Churn", data=df)

for container in ax.containers:
  ax.bar_label(container)
  plt.title("Churn count by Gender")
plt.show()

# %%
sns.countplot(x="Contract",hue="Churn",data=df)
plt.show()

# %%
sns.histplot(x="tenure",hue="Churn",data=df,bins=72)
plt.show()

# %%
sns.boxplot(x="Churn",y="MonthlyCharges",data=df)
plt.show()

# %% [markdown]
# Data cleaning and preprocessing

# %%
df["TotalCharges"].dtype
# Out:
# dtype('O')

# %%
df["TotalCharges"].head(10)
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# 5      820.5
# 6     1949.4
# 7      301.9
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: object

# %%
(df["TotalCharges"]==" ").sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"]=pd.to_numeric(df["TotalCharges"],errors="coerce")

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (7032, 21)

# %%
df=df.drop("customerID",axis=1)

# %%
df.shape
# Out:
# (7032, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(22)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (7010, 20)

# %%
####Categorical Encoding-Convert text to numbers

# %%
####Those coluns that contain two values-yes /no etc will be converted to 0/1 -label encoding
####columns with more than 2 values like contracts-one month/one year/ two year will be converted by one-hot encoding

# %%
df["InternetService"].value_counts()
# Out:
# InternetService
# Fiber optic    3090
# DSL            2414
# No             1506
# Name: count, dtype: int64

# %%
two_value_columns=["Churn","Partner","Dependents","PhoneService","PaperlessBilling","gender"]
for col in two_value_columns:
  df[col]=df[col].map({"Yes":1,"No":0,"Male":1,"Female":0})

# %%
df[two_value_columns].head()
# Out:
#    Churn  Partner  Dependents  PhoneService  PaperlessBilling  gender
# 0      0        1           0             0                 1       0
# 1      0        0           0             1                 0       1
# 2      1        0           0             1                 1       1
# 3      0        0           0             0                 0       1
# 4      1        0           0             1                 1       0

# %%
multi_value_columns=df.select_dtypes(include="object").columns
print(multi_value_columns)
# Out:
# Index(['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaymentMethod'],
#       dtype='object')

# %%
####applying one-hot encoding

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.shape
# Out:
# (7010, 20)

# %%
df = pd.get_dummies(df, columns=multi_value_columns, drop_first=True)

# %%
df.dtypes
# Out:
# gender                                     int64
# SeniorCitizen                              int64
# Partner                                    int64
# Dependents                                 int64
# tenure                                     int64
# PhoneService                               int64
# PaperlessBilling                           int64
# MonthlyCharges                           float64
# TotalCharges                             float64
# Churn                                      int64
# MultipleLines_No phone service              bool
# MultipleLines_Yes                           bool
# InternetService_Fiber optic                 bool
# InternetService_No                          bool
# OnlineSecurity_No internet service          bool
# OnlineSecurity_Yes                          bool
# OnlineBackup_No internet service            bool
# OnlineBackup_Yes                            bool
# DeviceProtection_No internet service        bool
# ...

# %%
df.dtypes.value_counts()
# Out:
# bool       21
# int64       8
# float64     2
# Name: count, dtype: int64

# %%
####Seperating feature and target SPLIT DATASET

# %%
X=df.drop(["Churn"],axis=1)
Y=df["Churn"]
#### drop(labels,axis =row/column)

# %%
####Now train test split
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
#80% training data , 20% testing, random_state=42 ensures reproducability

# %%
print(df.dtypes)
print(df.head())
# Out:
# gender                                     int64
# SeniorCitizen                              int64
# Partner                                    int64
# Dependents                                 int64
# tenure                                     int64
# PhoneService                               int64
# PaperlessBilling                           int64
# MonthlyCharges                           float64
# TotalCharges                             float64
# Churn                                      int64
# MultipleLines_No phone service              bool
# MultipleLines_Yes                           bool
# InternetService_Fiber optic                 bool
# InternetService_No                          bool
# OnlineSecurity_No internet service          bool
# OnlineSecurity_Yes                          bool
# OnlineBackup_No internet service            bool
# OnlineBackup_Yes                            bool
# DeviceProtection_No internet service        bool
# ...

# %% [markdown]
# Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(X_train,Y_train)

coef=model.coef_[0]
intercept=model.intercept_[0]


print("model coefficients are", coef)
print("model intercept is", intercept)
# Out:
# model coefficients are [-2.47701908e-02  3.11231093e-01  4.15691756e-02 -2.51138551e-01
#  -6.73290423e-02 -4.30849536e-01  4.43213101e-01  4.64902547e-03
#   3.78015466e-04  3.08453111e-01  2.49198355e-01  4.82931595e-01
#  -1.19432988e-01 -1.19432988e-01 -5.72450107e-01 -1.19432988e-01
#  -2.03290620e-01 -1.19432988e-01 -1.30437954e-01 -1.19432988e-01
#  -5.27033187e-01 -1.19432988e-01  1.51696309e-01 -1.19432988e-01
#   1.80220904e-01 -4.41391697e-01 -6.59979340e-01 -1.35451431e-01
#   2.29632369e-01 -3.48717446e-02]
# model intercept is -0.12457888261510164
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print("model coefficients are", coef)
print("model intercept is", intercept)
# Out:
# model coefficients are [-2.47701908e-02  3.11231093e-01  4.15691756e-02 -2.51138551e-01
#  -6.73290423e-02 -4.30849536e-01  4.43213101e-01  4.64902547e-03
#   3.78015466e-04  3.08453111e-01  2.49198355e-01  4.82931595e-01
#  -1.19432988e-01 -1.19432988e-01 -5.72450107e-01 -1.19432988e-01
#  -2.03290620e-01 -1.19432988e-01 -1.30437954e-01 -1.19432988e-01
#  -5.27033187e-01 -1.19432988e-01  1.51696309e-01 -1.19432988e-01
#   1.80220904e-01 -4.41391697e-01 -6.59979340e-01 -1.35451431e-01
#   2.29632369e-01 -3.48717446e-02]
# model intercept is -0.12457888261510164

# %%
####prediction
y_pred=model.predict(X_test)

# %%
####Performance
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

print ("Accuracy:" ,accuracy_score(Y_test,y_pred))
print("Confusion Matrix:\n", confusion_matrix(Y_test,y_pred))
print("Classification Report :\n ", classification_report(Y_test,y_pred))


####confusion matrix-> TP=CHURN PREDICTED CORRECTLY
#TN-> NO CHURN PREDICTED CORRECTLY
#FP-> PREDICTED CHURN BUT ACTUALLY NO CHURN(FALSE POSITIVES)
#FN-> PREDICTED NO CHURN BUT ACTUALLY CHURN (FALSE NEGATIVES)


####Accuracy score->percentage of correct predictions
# Out:
# Accuracy: 0.8238231098430813
# Confusion Matrix:
#  [[972 109]
#  [138 183]]
# Classification Report :
#                 precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      1081
#            1       0.63      0.57      0.60       321
#
#     accuracy                           0.82      1402
#    macro avg       0.75      0.73      0.74      1402
# weighted avg       0.82      0.82      0.82      1402

# %%
coef_series=pd.Series(coef,index=X_train.columns)
coef_series=coef_series.sort_values()

coef_series.plot(kind="barh")
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.show()


####this shows which features increase or decrease the likelihood of churn

# %% [markdown]
# Random Forest
#
#
# Each tress votes on churn prediction
# n_estimators->100 trees

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf=RandomForestClassifier(n_estimators=100,random_state=42)
model_rf.fit(X_train,Y_train)
y_pred_rf=model_rf.predict(X_test)


print("Random Forest Accuracy:", accuracy_score(Y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred_rf))
print("Classification report:", classification_report(Y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.8138373751783167
# Confusion Matrix:
#  [[971 110]
#  [151 170]]
# Classification report:               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      1081
#            1       0.61      0.53      0.57       321
#
#     accuracy                           0.81      1402
#    macro avg       0.74      0.71      0.72      1402
# weighted avg       0.81      0.81      0.81      1402

# %%
importance=pd.Series(model_rf.feature_importances_,index=X_train.columns)
importance=importance.sort_values()
print(importance.head())
# Out:
# DeviceProtection_No internet service    0.003468
# MultipleLines_No phone service          0.003997
# PhoneService                            0.004426
# StreamingTV_No internet service         0.004640
# TechSupport_No internet service         0.004975
# dtype: float64

# %%
importance.plot(kind='barh')
plt.show()

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_nb=GaussianNB()

# %%
model_nb.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb=model_nb.predict(X_test)

# %%
print("Naive Bayes Accuracy:", accuracy_score(Y_test, y_pred_nb))
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred_nb))
print("Classification Report:\n", classification_report(Y_test, y_pred_nb))
# Out:
# Naive Bayes Accuracy: 0.645506419400856
# Confusion Matrix:
#  [[618 463]
#  [ 34 287]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.57      0.71      1081
#            1       0.38      0.89      0.54       321
#
#     accuracy                           0.65      1402
#    macro avg       0.67      0.73      0.62      1402
# weighted avg       0.82      0.65      0.67      1402

# %% [markdown]
# KNN CLASSIFIER

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

X_train_sc=sc.fit_transform(X_train)
X_test_sc=sc.transform(X_test)

from sklearn.neighbors import KNeighborsClassifier


model_knn=KNeighborsClassifier(n_neighbors=3)
model_knn.fit(X_train_sc,Y_train)
y_pred_knn=model_knn.predict(X_test_sc)

print("KNN Accuracy:", accuracy_score(Y_test, y_pred_knn))
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred_knn))
print("Classification Report:\n", classification_report(Y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.7660485021398002
# Confusion Matrix:
#  [[902 179]
#  [149 172]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      1081
#            1       0.49      0.54      0.51       321
#
#     accuracy                           0.77      1402
#    macro avg       0.67      0.69      0.68      1402
# weighted avg       0.77      0.77      0.77      1402

# %% [markdown]
# SVM classifier

# %%
from sklearn.svm import SVC

# SVM also needs scaled data like KNN
model_svm = SVC(probability=True, random_state=42)
model_svm.fit(X_train_sc, Y_train)
y_pred_svm = model_svm.predict(X_test_sc)

print("SVM Accuracy:", accuracy_score(Y_test, y_pred_svm))
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred_svm))
print("Classification Report:\n", classification_report(Y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.8209700427960057
# Confusion Matrix:
#  [[986  95]
#  [156 165]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89      1081
#            1       0.63      0.51      0.57       321
#
#     accuracy                           0.82      1402
#    macro avg       0.75      0.71      0.73      1402
# weighted avg       0.81      0.82      0.81      1402

# %% [markdown]
# Evaluation

# %%
#Area under ROC

# %%
#### Sensitivity(SN) TPR=SN and FPR=(1-sensitivity(SP))

# %%
####SN=TP/TP+FN AND SP=TN/TN+FP

# %%
####ROC-AUC -How well each model discriminates churn vs non-churn

# %%
from sklearn.metrics import roc_curve, roc_auc_score


models = {
    "Random Forest": model_rf,
    "Logistic Regression": model,
    "Naive Bayes": model_nb,
    "KnnClassifier":model_knn,
    "SVM Classifier":model_svm
}



for name, mdl in models.items():

  if name in ["KnnClassifier","SVM Classifier"]:
    y_prob=mdl.predict_proba(X_test_sc)[:,1]
  else:
    y_prob = mdl.predict_proba(X_test)[:,1]
  fpr, tpr, _ = roc_curve(Y_test, y_prob)
  auc = roc_auc_score(Y_test, y_prob)
  plt.plot(fpr, tpr, label=f"{name} (AUC={auc:.2f})")

# Plot diagonal line
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()

# %%
###SMOTE TO TREAT CLASS IMBALANCE

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(random_state=42)

X_train_smote,Y_train_smote=smote.fit_resample(X_train,Y_train)

print("Before smote", Y_train.value_counts())
print("After smote", Y_train_smote.value_counts())
# Out:
# Before smote Churn
# 0    4072
# 1    1536
# Name: count, dtype: int64
# After smote Churn
# 0    4072
# 1    4072
# Name: count, dtype: int64

# %%
#### Retraining all models with smote

# %%
model_lr_smote=LogisticRegression()
model_lr_smote.fit(X_train_smote,Y_train_smote)
Y_pred_lr_smote=model_lr_smote.predict(X_test)

model_rf_smote=RandomForestClassifier(n_estimators=100,random_state=42)
model_rf_smote.fit(X_train_smote,Y_train_smote)
Y_pred_rf_smote=model_rf_smote.predict(X_test)

sc=StandardScaler()

X_train_smote_sc=sc.fit_transform(X_train_smote)
X_test_sc=sc.fit_transform(X_test)

model_knn_smote=KNeighborsClassifier(n_neighbors=3)
model_knn_smote.fit(X_train_smote_sc,Y_train_smote)
Y_pred_knn_smote=model_knn_smote.predict(X_test_sc)

model_nb_smote=GaussianNB()
model_nb_smote.fit(X_train_smote,Y_train_smote)
Y_pred_nb_smote=model_nb_smote.predict(X_test)

model_svm_smote=SVC(probability=True, random_state=42)
model_svm_smote.fit(X_train_smote_sc,Y_train_smote)
Y_pred_svm_smote=model_svm_smote.predict(X_test_sc)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.metrics import accuracy_score, classification_report

models_smote = {
    "Logistic Regression": Y_pred_lr_smote,
    "Random Forest": Y_pred_rf_smote,
    "Naive Bayes": Y_pred_nb_smote,
    "KNN": Y_pred_knn_smote,
    "SVM": Y_pred_svm_smote
}

for name, y_pred in models_smote.items():
    print(f"\n{name} with SMOTE:")
    print("Accuracy:", accuracy_score(Y_test, y_pred))
    print("Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Logistic Regression with SMOTE:
# Accuracy: 0.7660485021398002
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84      1081
#            1       0.49      0.64      0.56       321
#
#     accuracy                           0.77      1402
#    macro avg       0.69      0.72      0.70      1402
# weighted avg       0.79      0.77      0.78      1402
#
#
# Random Forest with SMOTE:
# Accuracy: 0.7717546362339515
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      1081
#            1       0.50      0.58      0.54       321
#
#     accuracy                           0.77      1402
#    macro avg       0.69      0.70      0.69      1402
# weighted avg       0.78      0.77      0.78      1402
#
#
# Naive Bayes with SMOTE:
# Accuracy: 0.6141226818830242
# Classification Report:
# ...

# %%
####ROC CURVE WITH SMOTE

# %%
from sklearn.metrics import roc_curve, roc_auc_score


models = {
    "Random Forest": model_rf_smote,
    "Logistic Regression": model_lr_smote,
    "Naive Bayes": model_nb_smote,
    "KnnClassifier":model_knn_smote,
    "SVM Classifier":model_svm_smote
}



for name, mdl in models.items():

  if name in ["KnnClassifier","SVM Classifier"]:
    y_prob=mdl.predict_proba(X_test_sc)[:,1]
  else:
    y_prob = mdl.predict_proba(X_test)[:,1]
  fpr, tpr, _ = roc_curve(Y_test, y_prob)
  auc = roc_auc_score(Y_test, y_prob)
  plt.plot(fpr, tpr, label=f"{name} (AUC={auc:.2f})")

# Plot diagonal line
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()

# %% [markdown]
# SMOTE (Synthetic minority oversampling technique) treats all minority points equally, it
# does not care if some points are harder to classify for example boys are 90 and girls are 10, so SMOTE would make fake minority points (girls)

# %% [markdown]
# ADASYN (Adaptive synthetic technique) is another technique to handle class imbalance, and it focuses on the minority points that are harder to classify, for example, if girl A (surrounded by many boys) , girl B (surrounded by many girls), so, would give priority to girl A(harder to classify as surrounded by the majority group), creates more points for such harder ones, and fewer points for the easy ones

# %%
####ADASYN

# %%
from imblearn.over_sampling import ADASYN


adasyn=ADASYN(random_state=42)

X_train_adasyn,Y_train_adasyn=adasyn.fit_resample(X_train,Y_train)

print("Before ADASYN", Y_train.value_counts())
print("After ADASYN", Y_train_adasyn.value_counts())
# Out:
# Before ADASYN Churn
# 0    4072
# 1    1536
# Name: count, dtype: int64
# After ADASYN Churn
# 0    4072
# 1    4008
# Name: count, dtype: int64

# %%
model_lr_adasyn=LogisticRegression()
model_lr_adasyn.fit(X_train_adasyn,Y_train_adasyn)
Y_pred_lr_adasyn=model_lr_adasyn.predict(X_test)

model_rf_adasyn=RandomForestClassifier(n_estimators=100,random_state=42)
model_rf_adasyn.fit(X_train_adasyn,Y_train_adasyn)
Y_pred_rf_adasyn=model_rf_adasyn.predict(X_test)

sc=StandardScaler()

X_train_adasyn_sc=sc.fit_transform(X_train_adasyn)
X_test_sc=sc.fit_transform(X_test)

model_knn_adasyn=KNeighborsClassifier(n_neighbors=3)
model_knn_adasyn.fit(X_train_adasyn_sc,Y_train_adasyn)
Y_pred_knn_adasyn=model_knn_adasyn.predict(X_test_sc)

model_nb_adasyn=GaussianNB()
model_nb_adasyn.fit(X_train_adasyn,Y_train_adasyn)
Y_pred_nb_adasyn=model_nb_smote.predict(X_test)

model_svm_adasyn=SVC(probability=True, random_state=42)
model_svm_adasyn.fit(X_train_adasyn_sc,Y_train_adasyn)
Y_pred_svm_adasyn=model_svm_adasyn.predict(X_test_sc)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score, classification_report

models_adasyn = {
    "Logistic Regression": Y_pred_lr_adasyn,
    "Random Forest": Y_pred_rf_adasyn,
    "Naive Bayes": Y_pred_nb_adasyn,
    "KNN": Y_pred_knn_adasyn,
    "SVM": Y_pred_svm_adasyn
}

for name, y_pred in models_adasyn.items():
    print(f"\n{name} with ADASYN:")
    print("Accuracy:", accuracy_score(Y_test, y_pred))
    print("Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Logistic Regression with ADASYN:
# Accuracy: 0.7560627674750356
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83      1081
#            1       0.48      0.64      0.55       321
#
#     accuracy                           0.76      1402
#    macro avg       0.68      0.71      0.69      1402
# weighted avg       0.79      0.76      0.77      1402
#
#
# Random Forest with ADASYN:
# Accuracy: 0.7738944365192582
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1081
#            1       0.51      0.60      0.55       321
#
#     accuracy                           0.77      1402
#    macro avg       0.69      0.71      0.70      1402
# weighted avg       0.79      0.77      0.78      1402
#
#
# Naive Bayes with ADASYN:
# Accuracy: 0.6141226818830242
# Classification Report:
# ...

# %%
from sklearn.metrics import roc_curve, roc_auc_score


models = {
    "Random Forest": model_rf_adasyn,
    "Logistic Regression": model_lr_adasyn,
    "Naive Bayes": model_nb_adasyn,
    "KnnClassifier":model_knn_adasyn,
    "SVM Classifier":model_svm_adasyn
}



for name, mdl in models.items():

  if name in ["KnnClassifier","SVM Classifier"]:
    y_prob=mdl.predict_proba(X_test_sc)[:,1]
  else:
    y_prob = mdl.predict_proba(X_test)[:,1]
  fpr, tpr, _ = roc_curve(Y_test, y_prob)
  auc = roc_auc_score(Y_test, y_prob)
  plt.plot(fpr, tpr, label=f"{name} (AUC={auc:.2f})")

# Plot diagonal line
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()
